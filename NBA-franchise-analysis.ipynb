# %%
import csv
import pandas as pd
import string
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure
import numpy as np

# %%
file_path = 'NBA-Complete.csv'

NBA_df = pd.read_csv(file_path)
NBA_df.fillna(0)
# Out:
#                       Team  Age (2017)  W (2017)  L (2017)  Pct (2017)  \
# 0            Atlanta Hawks        27.9        43        39       0.524
# 1           Boston Celtics        25.9        53        29       0.646
# 2            Brooklyn Nets        26.0        20        62       0.244
# 3        Charlotte Hornets        26.5        36        46       0.439
# 4            Chicago Bulls        26.9        41        41       0.500
# 5      Cleveland Cavaliers        29.2        51        31       0.622
# 6         Dallas Mavericks        27.6        33        49       0.402
# 7           Denver Nuggets        25.2        40        42       0.488
# 8          Detroit Pistons        25.4        37        45       0.451
# 9    Golden State Warriors        28.2        67        15       0.817
# 10         Houston Rockets        27.4        55        27       0.671
# 11          Indiana Pacers        27.0        42        40       0.512
# 12    Los Angeles Clippers        30.0        51        31       0.622
# 13      Los Angeles Lakers        25.1        26        56       0.317
# 14       Memphis Grizzlies        29.5        43        39       0.524
# 15              Miami Heat        26.5        41        41       0.500
# 16         Milwaukee Bucks        25.6        42        40       0.512
# 17  Minnesota Timberwolves        24.0        31        51       0.378
# 18    New Orleans Pelicans        25.7        34        48       0.415
# 19         New York Knicks        27.3        31        51       0.378
# 20   Oklahoma City Thunder        24.7        47        35       0.573
# 21           Orlando Magic        25.3        29        53       0.354
# 22      Philadelphia 76ers        24.6        28        54       0.341
# 23            Phoenix Suns        25.0        24        58       0.293
# 24  Portland Trail Blazers        24.8        41        41       0.500
# 25        Sacramento Kings        27.9        32        50       0.390
# 26       San Antonio Spurs        29.6        61        21       0.744
# 27         Toronto Raptors        26.1        51        31       0.622
# 28               Utah Jazz        26.8        51        31       0.622
# 29      Washington Wizards        26.0        49        33       0.598
#
#     Attend. (2017)  Income (2017)  All Stars (2017)  Age (2018)  W (2018)  \
# 0           654306             22               1.0        25.4        24
# 1           760690             85               1.0        24.7        55
# 2           632608             52               0.0        25.1        28
# 3           710643             21               1.0        26.6        36
# 4           888882             95               1.0        24.4        27
# 5           843042             -6               2.0        30.6        50
# 6           811366             21               0.0        27.7        24
# 7           605585             49               0.0        25.1        46
# 8           655141             22               0.0        25.9        39
# 9           803436            120               4.0        28.8        58
# 10          695903             95               1.0        29.8        65
# 11          684578             29               1.0        26.2        48
# 12          782609             35               1.0        27.0        42
# 13          776917            136               0.0        23.7        35
# 14          677314             15               1.0        26.0        22
# 15          805400             63               0.0        26.5        44
# 16          648952             20               1.0        25.9        44
# 17          607203             53               0.0        27.1        47
# 18          663099             37               1.0        27.6        48
# 19          810741            140               1.0        26.3        29
# 20          746323             64               1.0        27.3        48
# 21          727875             39               0.0        25.6        25
# 22          710557             40               0.0        25.8        52
# 23          708639             31               0.0        23.7        21
# 24          792029             25               0.0        25.6        49
# 25          721928             50               1.0        26.4        27
# 26          755347             59               1.0        29.3        47
# 27          813050             51               2.0        25.8        59
# 28          806142             61               1.0        26.7        48
# 29          697107             21               1.0        26.9        43
#
#     ...  Attend. (2020)  Income (2020)  All Stars (2020)  Age (2021)  \
# 0   ...          545453             36               1.0        25.4
# 1   ...          610864             86               2.0        25.1
# 2   ...          524907             44               0.0        28.2
# 3   ...          478591             36               0.0        24.6
# 4   ...          639352            115               0.0        25.6
# 5   ...          643008             46               0.0        24.0
# 6   ...          682096             84               1.0        26.3
# 7   ...          633153             27               1.0        26.1
# 8   ...          509469             45               0.0        24.5
# 9   ...          614176            200               0.0        26.7
# 10  ...          578458             94               2.0        26.5
# 11  ...          529002             39               1.0        26.5
# 12  ...          610176             57               1.0        28.8
# 13  ...          588907            155               2.0        28.2
# 14  ...          523297             22               0.0        24.2
# 15  ...          629771             38               2.0        27.4
# 16  ...          549036             27               2.0        28.1
# 17  ...          482112             32               0.0        23.2
# 18  ...          528172             44               1.0        24.8
# 19  ...          620789            178               0.0        25.6
# 20  ...          600699             51               1.0        22.8
# 21  ...          529870             37               0.0        25.6
# 22  ...          639491             51               2.0        27.1
# 23  ...          550633             20               1.0        26.6
# 24  ...          628303             27               0.0        27.4
# 25  ...          520663             45               0.0        25.6
# 26  ...          550515             63               0.0        26.2
# 27  ...          633456             79               2.0        26.6
# 28  ...          567486             42               2.0        28.5
# 29  ...          532702             39               0.0        26.6
#
#     W (2021)  L (2021)  Pct (2021)  Attend. (2021)  Income (2021)  \
# 0         41        31       0.569         59288.0             37
# 1         36        36       0.500         30067.0             46
# 2         48        24       0.667         30491.0            -80
# 3         33        39       0.458         68255.0             34
# 4         31        41       0.431         13655.0             39
# 5         22        50       0.306         91476.0             11
# 6         42        30       0.583         94849.0             55
# 7         47        25       0.653         54563.0             15
# 8         20        52       0.278         14250.0             43
# 9         39        33       0.542         33457.0            -44
# 10        17        55       0.236        117009.0             33
# 11        34        38       0.472             0.0              4
# 12        47        25       0.653         13901.0             18
# 13        42        30       0.583         23313.0             63
# 14        38        34       0.528         61449.0             12
# 15        40        32       0.556             0.0             16
# 16        46        26       0.639         64780.0             11
# 17        23        49       0.319         15774.0             29
# 18        31        41       0.431         93120.0             24
# 19        41        31       0.569         42131.0             71
# 20        22        50       0.306             0.0             48
# 21        21        51       0.292        126463.0             29
# 22        49        23       0.681         68583.0             13
# 23        51        21       0.708        104027.0             15
# 24        42        30       0.583          5817.0             19
# 25        31        41       0.431             0.0             25
# 26        33        39       0.458         61053.0             39
# 27        27        45       0.375         26024.0              2
# 28        52        20       0.722        151300.0             96
# 29        34        38       0.472         19198.0             15
#
#     All Stars (2021)
# 0                0.0
# 1                2.0
# 2                2.0
# 3                0.0
# 4                1.0
# 5                0.0
# 6                1.0
# 7                1.0
# 8                0.0
# 9                1.0
# 10               0.0
# 11               1.0
# 12               2.0
# 13               1.0
# 14               0.0
# 15               0.0
# 16               1.0
# 17               0.0
# 18               1.0
# 19               1.0
# 20               0.0
# 21               1.0
# 22               2.0
# 23               1.0
# 24               1.0
# 25               0.0
# 26               0.0
# 27               0.0
# 28               3.0
# 29               1.0
#
# [30 rows x 36 columns]

# %%
x = NBA_df['Team']
y1 = NBA_df['Pct (2017)']
y2 = NBA_df['Attend. (2017)']

figure(figsize=(600, 200), dpi=20)
plt.rc('font', size=10)

# Create the bar graph
fig, ax1 = plt.subplots()
ax1.bar(x, y1, color='y')
ax1.set_xlabel('Teams')
ax1.set_ylabel('Win %', color='k')

# Create the second set of y-axis labels
ax2 = ax1.twinx()
ax2.stem(x, y2)
ax2.set_ylabel('Attendance', color='k')

ax1.set_xticklabels(x, rotation=90)

# Show the plot
plt.show()
# Out:
# C:\Users\ulmat\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:16: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   app.launch_new_instance()

# %%
x = NBA_df['Team']
y1 = NBA_df['Pct (2019)']
y2 = NBA_df['Attend. (2019)']

figure(figsize=(300, 100), dpi=20)
plt.rc('font', size=10)

# Create the bar graph
fig, ax1 = plt.subplots()
ax1.bar(x, y1, color='y')
ax1.set_xlabel('Teams')
ax1.set_ylabel('Win %', color='k')

# Create the second set of y-axis labels
ax2 = ax1.twinx()
ax2.stem(x, y2)
ax2.set_ylabel('Attendance', color='k')

ax1.set_xticklabels(x, rotation=90)

# Show the plot
plt.show()
# Out:
# C:\Users\ulmat\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:16: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   app.launch_new_instance()

# %%
sns.set_style("whitegrid")

sns.lmplot(x="Age (2021)", y="Pct (2021)", data=NBA_df, line_kws={"color":"red"})
plt.xlabel("Average Team Age (2021)", fontweight='bold')
plt.ylabel("Team Win Percentage (2021)", fontweight='bold')

sns.lmplot(x="Age (2020)", y="Pct (2020)", data=NBA_df, line_kws={"color":"orange"})
plt.xlabel("Average Team Age (2020)", fontweight='bold')
plt.ylabel("Team Win Percentage (2020)", fontweight='bold')

sns.lmplot(x="Age(2019)", y="Pct (2019)", data=NBA_df, line_kws={"color":"blue"})
plt.xlabel("Average Team Age (2019)", fontweight='bold')
plt.ylabel("Team Win Percentage (2019)", fontweight='bold')

sns.lmplot(x="Age (2018)", y="Pct (2018)", data=NBA_df, line_kws={"color":"purple"})
plt.xlabel("Average Team Age (2018)", fontweight='bold')
plt.ylabel("Team Win Percentage (2018)", fontweight='bold')

sns.lmplot(x="Age (2017)", y="Pct (2017)", data=NBA_df, line_kws={"color":"green"})
plt.xlabel("Average Team Age (2017)", fontweight='bold')
plt.ylabel("Team Win Percentage (2017)", fontweight='bold')

plt.show()
